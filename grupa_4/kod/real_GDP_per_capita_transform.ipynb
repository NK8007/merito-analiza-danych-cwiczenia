# %%
import pandas as pd

data = pd.read_csv("C:\\Users\\Person\\Desktop\\Python_resources\\merito-analiza-danych-cwiczenia\\dane\\real_GDP_per_capita.csv")
print(data.head())
# Out:
#    #  geo\TIME_PERIOD  AT: Austria  BE: Belgium  BG: Bulgaria  CY: Cyprus  \
# 0  1             1995        30290        28400          3630       17530
# 1  2             1996        30920        28720          3840       17470
# 2  3             1997        31540        29740          3320       17680
# 3  4             1998        32610        30260          3460       18530
# 4  5             1999        33770        31250          3190       19240
#
#    CZ: Czech Republic  DE: Germany  DK: Denmark  \
# 0               10320        28960        39110
# 1               10770        29210        39990
# 2               10720        29730        41080
# 3               10690        30380        41900
# 4               10850        31040        43000
#
#    EA20: Euro Area (the 20 countries using the euro)  ...  LU: Luxembourg  \
# 0                                              24610  ...           67360
# 1                                              24980  ...           67480
# ...

# %%
print(data.describe())
# Out:
#                #  geo\TIME_PERIOD   AT: Austria   BE: Belgium  BG: Bulgaria  \
# count  29.000000        29.000000     29.000000     29.000000     29.000000
# mean   15.000000      2009.000000  37724.827586  35096.551724   5593.793103
# std     8.514693         8.514693   3447.035601   3224.204526   1743.916802
# min     1.000000      1995.000000  30290.000000  28400.000000   3190.000000
# 25%     8.000000      2002.000000  35430.000000  32990.000000   3840.000000
# 50%    15.000000      2009.000000  39140.000000  36060.000000   5690.000000
# 75%    22.000000      2016.000000  39870.000000  36860.000000   6840.000000
# max    29.000000      2023.000000  42540.000000  40370.000000   8850.000000
#
#          CY: Cyprus  CZ: Czech Republic   DE: Germany   DK: Denmark  \
# count     29.000000           29.000000     29.000000     29.000000
# mean   22523.793103        14560.689655  35088.965517  47065.172414
# std     3066.614482         2742.175793   3528.189889   4023.548204
# ...
