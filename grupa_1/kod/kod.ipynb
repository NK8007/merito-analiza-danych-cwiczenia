# %%
import pandas as pd

# %%
real_gdp_dataframe = pd.read_csv("../../dane/real_GDP_per_capita.csv")
gini_dataframe = pd.read_csv("../../dane/real_GDP_per_capita.csv")
population_dataframe = pd.read_csv("../../dane/real_GDP_per_capita.csv")

# %%
real_gdp_dataframe.head()
# Out:
#    #  geo\TIME_PERIOD  AT: Austria  BE: Belgium  BG: Bulgaria  CY: Cyprus  \
# 0  1             1995        30290        28400          3630       17530
# 1  2             1996        30920        28720          3840       17470
# 2  3             1997        31540        29740          3320       17680
# 3  4             1998        32610        30260          3460       18530
# 4  5             1999        33770        31250          3190       19240
#
#    CZ: Czech Republic  DE: Germany  DK: Denmark  \
# 0               10320        28960        39110
# 1               10770        29210        39990
# 2               10720        29730        41080
# 3               10690        30380        41900
# 4               10850        31040        43000
#
#    EA20: Euro Area (the 20 countries using the euro)  ...  LU: Luxembourg  \
# 0                                              24610  ...           67360
# 1                                              24980  ...           67480
# ...

# %%
real_gdp_dataframe.describe()
# Out:
#                #  geo\TIME_PERIOD   AT: Austria   BE: Belgium  BG: Bulgaria  \
# count  29.000000        29.000000     29.000000     29.000000     29.000000
# mean   15.000000      2009.000000  37724.827586  35096.551724   5593.793103
# std     8.514693         8.514693   3447.035601   3224.204526   1743.916802
# min     1.000000      1995.000000  30290.000000  28400.000000   3190.000000
# 25%     8.000000      2002.000000  35430.000000  32990.000000   3840.000000
# 50%    15.000000      2009.000000  39140.000000  36060.000000   5690.000000
# 75%    22.000000      2016.000000  39870.000000  36860.000000   6840.000000
# max    29.000000      2023.000000  42540.000000  40370.000000   8850.000000
#
#          CY: Cyprus  CZ: Czech Republic   DE: Germany   DK: Denmark  \
# count     29.000000           29.000000     29.000000     29.000000
# mean   22523.793103        14560.689655  35088.965517  47065.172414
# std     3066.614482         2742.175793   3528.189889   4023.548204
# ...

# %%
gini_dataframe.head()
# Out:
#        Country  Year  \
# 0  Afghanistan  1980
# 1  Afghanistan  1981
# 2  Afghanistan  1982
# 3  Afghanistan  1983
# 4  Afghanistan  1984
#
#    Gini coefficient (before tax) (World Inequality Database)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Income share of the richest 10% (before tax) (World Inequality Database)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Income share of the richest 1% (before tax) (World Inequality Database)  \
# 0                                                NaN
# ...

# %%
gini_dataframe.describe()
# Out:
#               Year  Gini coefficient (before tax) (World Inequality Database)  \
# count  9710.000000                                        4534.000000
# mean   1996.152008                                           0.538288
# std      21.569577                                           0.107790
# min    1820.000000                                           0.217636
# 25%    1988.000000                                           0.456309
# 50%    1999.000000                                           0.530896
# 75%    2010.000000                                           0.625598
# max    2022.000000                                           0.804305
#
#        Income share of the richest 10% (before tax) (World Inequality Database)  \
# count                                        6528.000000
# mean                                           43.246356
# std                                            10.414275
# min                                            16.910000
# ...

# %%
population_dataframe.head()
# Out:
#   country_code country_name  \
# 0          ABW        ARUBA
# 1          AFE          NaN
# 2          AFG   AFGANISTÁN
# 3          AFW          NaN
# 4          AGO       ANGOLA
#
#                                               region  \
# 0                                                NaN
# 1                                                NaN
# 2                                    ASIA MERIDIONAL
# 3                                                NaN
# 4  ÁFRICA AL SUR DEL SAHARA (EXCLUIDO ALTOS INGRE...
#
#                      income_group         1960         1961         1962  \
# 0                    INGRESO ALTO      54608.0      55811.0      56682.0
# 1                       AGREGADOS  130692579.0  134169237.0  137835590.0
# 2          PAÍSES DE INGRESO BAJO    8622466.0    8790140.0    8969047.0
# 3                       AGREGADOS   97256290.0   99314028.0  101445032.0
# 4  PAÍSES DE INGRESO MEDIANO BAJO    5357195.0    5441333.0    5521400.0
#
# ...

# %%
population_dataframe.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.157939e+08  1.173869e+08  1.195401e+08  1.222050e+08  1.248922e+08
# std    3.639920e+08  3.684672e+08  3.751049e+08  3.837174e+08  3.923714e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.708088e+06  3.816540e+06  3.931214e+06  4.033994e+06  4.112910e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031517e+09  3.072470e+09  3.126894e+09  3.193470e+09  3.260480e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.276182e+08  1.304676e+08  1.333152e+08  1.362430e+08  1.392759e+08
# ...
