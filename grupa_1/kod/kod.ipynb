# %%
import pandas as pd

# %%
real_gdp_df = pd.read_csv("../../dane/real_GDP_per_capita.csv")

# %%
real_gdp_df_1 = real_gdp_df.drop(["EA20: Euro Area (the 20 countries using the euro)", "EU27_2020: European Union 27 countries (after Brexit, excluding the UK)"], axis=1)

# %%
real_gdp_df_1.columns = [header.lower() for header in real_gdp_df_1.columns ]
real_gdp_df_1.head()
# Out:
#    #  year   austria   belgium   bulgaria   cyprus   czech republic   germany  \
# 0  1  1995     30290     28400       3630    17530            10320     28960
# 1  2  1996     30920     28720       3840    17470            10770     29210
# 2  3  1997     31540     29740       3320    17680            10720     29730
# 3  4  1998     32610     30260       3460    18530            10690     30380
# 4  5  1999     33770     31250       3190    19240            10850     31040
#
#     denmark   estonia  ...   luxembourg   latvia   malta   netherlands  \
# 0     39110      6410  ...        67360     4200       0         30570
# 1     39990      6840  ...        67480     4350       0         31470
# 2     41080      7830  ...        70230     4790       0         32640
# 3     41900      8250  ...        73970     5160       0         33940
# 4     43000      8300  ...        78880     5340       0         35420
#
#     poland   portugal   romania   sweden   slovenia   slovakia
# ...

# %%
real_gdp_df_1.head()
# Out:
#    #  year   austria   belgium   bulgaria   cyprus   czech republic   germany  \
# 0  1  1995     30290     28400       3630    17530            10320     28960
# 1  2  1996     30920     28720       3840    17470            10770     29210
# 2  3  1997     31540     29740       3320    17680            10720     29730
# 3  4  1998     32610     30260       3460    18530            10690     30380
# 4  5  1999     33770     31250       3190    19240            10850     31040
#
#     denmark   estonia  ...   luxembourg   latvia   malta   netherlands  \
# 0     39110      6410  ...        67360     4200       0         30570
# 1     39990      6840  ...        67480     4350       0         31470
# 2     41080      7830  ...        70230     4790       0         32640
# 3     41900      8250  ...        73970     5160       0         33940
# 4     43000      8300  ...        78880     5340       0         35420
#
#     poland   portugal   romania   sweden   slovenia   slovakia
# ...

# %%
real_gdp_df_2 = real_gdp_df_1.drop("#", axis=1)
real_gdp_df_transposed = real_gdp_df_2.transpose()
real_gdp_df_transposed.columns  = real_gdp_df_transposed.iloc[0]
real_gdp_df_transposed = real_gdp_df_transposed[1:]
real_gdp_df_transposed
# Out:
# year             1995   1996   1997   1998   1999   2000   2001   2002   2003  \
# austria         30290  30920  31540  32610  33770  34760  35090  35430  35680
# belgium         28400  28720  29740  30260  31250  32340  32580  32990  33190
# bulgaria         3630   3840   3320   3460   3190   3350   3600   3830   4050
# cyprus          17530  17470  17680  18530  19240  20180  20750  21270  21570
# czech republic  10320  10770  10720  10690  10850  11290  11680  11880  12270
# germany         28960  29210  29730  30380  31040  31920  32420  32320  32160
# denmark         39110  39990  41080  41900  43000  44450  44710  44770  44850
# estonia          6410   6840   7830   8250   8300   8990   9580  10310  11160
# greece          14290  14430  14870  15300  15650  16230  16890  17620  18600
# spain           18220  18620  19210  19960  20750  21730  22470  22720  22960
# finland         26940  27840  29530  31060  32340  34130  34960  35460  36090
# ...

# %%
real_gdp_df.describe()
# Out:
#                #         year       Austria       Belgium     Bulgaria  \
# count  29.000000    29.000000     29.000000     29.000000    29.000000
# mean   15.000000  2009.000000  37724.827586  35096.551724  5593.793103
# std     8.514693     8.514693   3447.035601   3224.204526  1743.916802
# min     1.000000  1995.000000  30290.000000  28400.000000  3190.000000
# 25%     8.000000  2002.000000  35430.000000  32990.000000  3840.000000
# 50%    15.000000  2009.000000  39140.000000  36060.000000  5690.000000
# 75%    22.000000  2016.000000  39870.000000  36860.000000  6840.000000
# max    29.000000  2023.000000  42540.000000  40370.000000  8850.000000
#
#              Cyprus   Czech Republic       Germany       Denmark  \
# count     29.000000        29.000000     29.000000     29.000000
# mean   22523.793103     14560.689655  35088.965517  47065.172414
# std     3066.614482      2742.175793   3528.189889   4023.548204
# min    17470.000000     10320.000000  28960.000000  39110.000000
# ...
